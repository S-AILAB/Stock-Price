# %% [markdown]
# <a href="https://colab.research.google.com/github/S-AILAB/Stock-Price/blob/main/Stock-price-yfinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# !pip install yahoofinancials
# !pip install fix-yahoo-finance
# !pip install --upgrade yfinance
# !pip install Yahoo-ticker-downloader

# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
aapl_df = yf.download('AAPL',
                      start='2024-01-01',
                      end='2024-07-12',
                      progress=False,
)
aapl_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  184.938217
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  183.553467
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.222336
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.495071
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  184.858521
#
#               Volume
# Date
# 2024-01-02  82488700
# 2024-01-03  58414500
# 2024-01-04  71983600
# 2024-01-05  62303300
# 2024-01-08  59144500

# %%
infy_df = yf.download('INFY.NS',
                      start='2024-01-01',
                      end='2024-06-23',
                      progress=False,
)
infy_df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-01-01  1539.000000  1557.000000  1535.250000  1551.349976  1542.655640
# 2024-01-02  1546.000000  1549.150024  1523.000000  1534.400024  1525.800659
# 2024-01-03  1519.949951  1519.949951  1488.000000  1490.000000  1481.649414
# 2024-01-04  1504.949951  1519.750000  1492.900024  1512.699951  1504.222168
# 2024-01-05  1506.750000  1539.699951  1506.250000  1532.550049  1523.961060
#
#              Volume
# Date
# 2024-01-01  2808451
# 2024-01-02  5396313
# 2024-01-03  7550363
# 2024-01-04  7056038
# 2024-01-05  8895403

# %%
infy_df = yf.download('LICI.NS',
                      progress=True,
)
infy_df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-05-17  872.000000  918.950012  860.000000  875.250000  856.956604
# 2022-05-18  885.549988  891.000000  874.099976  876.349976  858.033630
# 2022-05-19  867.000000  867.000000  838.000000  840.849976  823.275513
# 2022-05-20  848.549988  856.799988  825.000000  826.150024  808.882812
# 2022-05-23  826.150024  852.700012  803.650024  816.849976  799.777222
#
#               Volume
# Date
# 2022-05-17  48792877
# 2022-05-18   8919761
# 2022-05-19   7372427
# 2022-05-20   7078291
# 2022-05-23  12444648

# %% [markdown]
# # **LIC**

# %%
lic = yf.Ticker("LICI.NS")

# get all stock info
print(lic.info)
# Out:
# {'address1': 'Yogakshema', 'address2': '7th Floor, East Wing Jeevan Bima Marg Nariman Point', 'city': 'Mumbai', 'zip': '400021', 'country': 'India', 'phone': '91 22 2202 2079', 'website': 'https://www.licindia.in', 'industry': 'Insurance - Life', 'industryKey': 'insurance-life', 'industryDisp': 'Insurance - Life', 'sector': 'Financial Services', 'sectorKey': 'financial-services', 'sectorDisp': 'Financial Services', 'longBusinessSummary': 'Life Insurance Corporation of India provides life insurance products in India, Fiji, Mauritius, and the United Kingdom. It offers insurance plans, including endowment, whole life, term insurance plans, money back, and term assurance plans, as well as riders comprising accidental death and disability benefit, critical illness benefit, and premium waiver benefit riders. The company also provides pension, unit linked, micro insurance, withdrawal, and health plans, as well as various group schemes. Life Insurance Corporation of India was incorporated in
# ...

# %%
# get historical market data
hist = lic.history(period="1mo")
print(hist)
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2024-07-22 00:00:00+05:30  1100.000000  1146.400024  1090.000000  1123.699951
# 2024-07-23 00:00:00+05:30  1130.449951  1143.699951  1044.500000  1086.650024
# 2024-07-24 00:00:00+05:30  1090.000000  1170.000000  1088.150024  1160.550049
# 2024-07-25 00:00:00+05:30  1140.000000  1173.000000  1130.000000  1160.900024
# 2024-07-26 00:00:00+05:30  1165.000000  1197.000000  1151.050049  1184.349976
# 2024-07-29 00:00:00+05:30  1194.650024  1197.000000  1165.300049  1173.599976
# 2024-07-30 00:00:00+05:30  1173.599976  1192.449951  1163.800049  1188.099976
# 2024-07-31 00:00:00+05:30  1188.099976  1193.500000  1168.849976  1176.099976
# 2024-08-01 00:00:00+05:30  1183.150024  1222.000000  1176.050049  1179.150024
# 2024-08-02 00:00:00+05:30  1172.050049  1191.000000  1160.000000  1179.550049
# 2024-08-05 00:00:00+05:30  1154.000000  1154.000000  1087.000000  1107.650024
# ...

# %%
print(lic.news)
# Out:
# [{'uuid': '4c64559d-c362-3489-8fa1-b4d531527fea', 'title': 'Worried About a Recession? Buy These 3 Top Dividend Stocks and Relax.', 'publisher': 'Motley Fool', 'link': 'https://finance.yahoo.com/m/4c64559d-c362-3489-8fa1-b4d531527fea/worried-about-a-recession%3F.html', 'providerPublishTime': 1724315760, 'type': 'STORY', 'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/J3HXUDIJ1UGfKjmo2If5BQ--~B/aD00MDIxO3c9NjA0MzthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/b7db6eaecd03baddbb539d12c16b4806', 'width': 6043, 'height': 4021, 'tag': 'original'}, {'url': 'https://s.yimg.com/uu/api/res/1.2/5gtsci_F7B6kJp8.j1AWnQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/b7db6eaecd03baddbb539d12c16b4806', 'width': 140, 'height': 140, 'tag': '140x140'}]}, 'relatedTickers': ['CVX', 'ITW']}, {'uuid': 'b5d1567c-4ff4-3b88-9ed7-28f7e0bed350', 'title': 'Innovent’s Dupert approved in China to treat lung cancer', 
# ...

# %%
tickers = yf.Tickers('msft aapl goog')

# access each ticker using (example)
tickers.tickers['MSFT'].info
tickers.tickers['AAPL'].history(period="1mo")
tickers.tickers['GOOG'].actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2014-03-27 00:00:00-04:00        0.0      2.002000
# 2015-04-27 00:00:00-04:00        0.0      1.002746
# 2022-07-18 00:00:00-04:00        0.0     20.000000
# 2024-06-10 00:00:00-04:00        0.2      0.000000

# %%
import yfinance as yf
data = yf.download("SPY AAPL", period="1mo")
print(data.head())
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Price        Adj Close                   Close                    High  \
# Ticker            AAPL         SPY        AAPL         SPY        AAPL
# Date
# 2024-07-22  223.701080  554.650024  223.960007  554.650024  227.779999
# 2024-07-23  224.749847  553.780029  225.009995  553.780029  226.940002
# 2024-07-24  218.287323  541.229980  218.539993  541.229980  224.800003
# 2024-07-25  217.238556  538.409973  217.490005  538.409973  220.850006
# 2024-07-26  217.708008  544.440002  217.960007  544.440002  219.490005
#
# Price                          Low                    Open              \
# Ticker             SPY        AAPL         SPY        AAPL         SPY
# Date
# 2024-07-22  555.270020  223.089996  551.020020  227.009995  553.000000
# 2024-07-23  556.739990  222.679993  553.280029  224.369995  554.539978
# 2024-07-24  549.169983  217.130005  540.289978  224.000000  548.859985
# ...
